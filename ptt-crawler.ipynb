# %% [markdown]
# # ptt 爬蟲實戰
#
# 先載入要使用的套件

# %%
import sys
import os
import requests
import json
import time
import re

# %% [markdown]
# 建立一個簡單的 debug 小函式，可以幫我們把爬下來的東西存成html，用瀏覽器檢視

# %%
def save_html(text):
    with open('saved.html', 'w', encoding="utf8") as f:
        f.write(text)

# %% [markdown]
# ## 如何爬取整個網頁
# 我寫一個爬蟲函式作為範例，爬取表特版的首頁

# %%
url = 'https://www.ptt.cc/bbs/Beauty/'
def crawl_board():
    res = requests.get(url=url)
    print(res)
#     print(res.text)
    save_html(res.text)

crawl_board()
# Out:
# <Response [200]>

# %% [markdown]
# ## 爬取不同的版
# 多加一個參數控制要爬取的版
#
# ### 小注意
# PTT有個已滿18歲的確認頁面，如要避開，請加上這個參數 `cookies={'over18': '1'}` 到 `requests.get`內

# %%
base_url = 'https://www.ptt.cc/bbs/'
def crawl_board(board_name):
    url = base_url + board_name
    res = requests.get(url=url)
    # res = requests.get(url=url, cookies={'over18': '1'})

    print(res)
#     print(res.text)
    save_html(res.text)

crawl_board('Gossiping')
# Out:
# <Response [200]>

# %% [markdown]
# ### 我們現在都只看的到某個版的最後一頁，如果想要看其他頁呢?
#
# 這個時候就需要一點人工觀察，例如八卦版的頁面網址長這樣
# ```
# https://www.ptt.cc/bbs/Gossiping/index39241.html
# ```
# 分析來看是: base url + 版名 + 版頁數的組成的一些東西

# %%
base_url = 'https://www.ptt.cc/bbs/'
def crawl_board(board_name, board_page):
    url = base_url + board_name + '/index' + str(board_page) + '.html'
    # res = requests.get(url=url)
    res = requests.get(url=url, cookies={'over18': '1'})

    print(res)
    # print(res.text)
    save_html(res.text)

crawl_board('Gossiping', 36999)
# Out:
# <Response [200]>

# %% [markdown]
# ### 爬取內文
#
# 我們已經可以自由的選擇版面和頁數了，這時候如果我們想要爬內文呢?
# 例如:
# https://www.ptt.cc/bbs/Gossiping/M.1553696869.A.7F7.html

# %%
def crawl_page(page_url):
    # res = requests.get(url=url)
    res = requests.get(url=page_url, cookies={'over18': '1'})

    print(res)
    # print(res.text)
    save_html(res.text)

crawl_page('https://www.ptt.cc/bbs/Gossiping/M.1553696869.A.7F7.html')
# Out:
# <Response [200]>

# %% [markdown]
# # 自動化 (讓 Python 像人一樣操縱瀏覽器)
#
# 現在都還是我們自己去輸入要爬的頁面，需要耗費人工的力氣。
#
# ## 解析 html
#
# 使用 Beautiful Soup 解析爬取的網頁，可以透過這個找到 **按鈕連結** 和 **網站的內容**
#
# ```python
# soup = BeautifulSoup(res.text, 'html.parser')
# ```

# %%
from bs4 import BeautifulSoup
print(BeautifulSoup)
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
base_url = 'https://www.ptt.cc/bbs/'
def crawl_board(board_name, board_page):
    url = base_url + board_name + '/index' + str(board_page) + '.html'

    res = requests.get(url=url, cookies={'over18': '1'})
    print('正在爬取', url)
    save_html(res.text)
    
    soup = BeautifulSoup(res.text, 'html.parser')
    print(soup.title)
    
    page_titles = soup.find_all(class_='title')
    print(page_titles)
    print(len(page_titles))
    
crawl_board('Gossiping', 36999)
# Out:
# 正在爬取 https://www.ptt.cc/bbs/Gossiping/index36999.html
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
# [<div class="title">
# <a href="/bbs/Gossiping/M.1551924564.A.E16.html">[問卦] 蔡政府不是說超收稅金要發錢補助窮人/?</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1551924577.A.636.html">[問卦] 喝葷茶是什麼？</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1551924643.A.86B.html">[新聞] 老爺爺買下波音727！建成「巨型精密豪宅</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1551924769.A.1C4.html">[新聞] 三立、壹電視新聞台「非洲豬瘟」內容遭NC</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1551924775.A.CE4.html">Re: [問卦] 尼特羅會長 VS 全部幻影旅團，哪邊會贏?</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1551924801.A.E1E.html">[新聞] 王金平今宣布參選2020總統</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1551924875.A.B9C.html">Re: [問卦] 認真玩相機跟音響哪個比較貴？</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1551924911.A.2CE.html">Re: [新聞] 柯粉快護駕! (訪美行程比一比</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1551924932.A.B0A.html">[問卦] 計程車司機有考核制度嗎？</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1551924987.A.EF7.html">Re: [新聞] 老爺爺買下波音727！建成「巨型精密豪宅</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1551925021.A.65D.html">Re: [問卦] 七年級生是不是很多人都放棄人生了</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1551925048.A.D0F.html">Re: [問卦] 七年級生是不是很多人都放棄人生了</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1551925054.A.FDE.html">Re: [新聞] 做1天公務員換來冤獄7年！最衰土木教授</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1551925085.A.77E.html">Re: [爆卦] 中時最新民調 柯文哲GG了</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1551925130.A.CB1.html">Re: [新聞] 最新民調 韓大幅領先柯</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1551925182.A.EDA.html">[問卦] 有沒有系上活動名稱的八卦？在線等</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1551925234.A.106.html">[問卦] 為什麼插頭有些沒洞</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1551925241.A.FB2.html">Re: [問卦] 計程車司機是不是過太爽？</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1551925267.A.F6D.html">Re: [新聞] 潘斯批民主黨：全民健保是社會主義</a>
# </div>, <div class="title">
# <a href="/bbs/Gossiping/M.1551925301.A.E55.html">[問卦] 奧斯卡獎真的有政治正確嘛</a>
# </div>]
# 20

# %% [markdown]
# ## 進一步讀取內部資訊
#
# HTML是一個格式，資訊都用`<>`包起來，我們可以進一步解析連結網址與標題

# %%
base_url = 'https://www.ptt.cc/bbs/'
def crawl_board(board_name, board_page):
    url = base_url + board_name + '/index' + str(board_page) + '.html'

    res = requests.get(url=url, cookies={'over18': '1'})
    print('正在爬取', url)
    save_html(res.text)
    
    soup = BeautifulSoup(res.text, 'html.parser')
    sub_pages = soup.find_all('div', class_='r-ent')
    sub_pages = sub_pages[:5]
    
    for sub_page in sub_pages:
        
        # 找推數
        push_info = sub_page.find(class_='nrec').find('span')
        if push_info != None:
            num_push = push_info.text
        else:
            num_push = 0
            
        # 找連結資訊
        link = sub_page.find('a')
        link_url = link['href']
        link_title = link.text
        
        # 找日期
        date = sub_page.find(class_='date').text
        
        print(link_url, link_title, num_push, date)

crawl_board('Gossiping', 36999)
# Out:
# 正在爬取 https://www.ptt.cc/bbs/Gossiping/index36999.html
# /bbs/Gossiping/M.1551924564.A.E16.html [問卦] 蔡政府不是說超收稅金要發錢補助窮人/? 0  3/07
# /bbs/Gossiping/M.1551924577.A.636.html [問卦] 喝葷茶是什麼？ 3  3/07
# /bbs/Gossiping/M.1551924643.A.86B.html [新聞] 老爺爺買下波音727！建成「巨型精密豪宅 13  3/07
# /bbs/Gossiping/M.1551924769.A.1C4.html [新聞] 三立、壹電視新聞台「非洲豬瘟」內容遭NC 0  3/07
# /bbs/Gossiping/M.1551924775.A.CE4.html Re: [問卦] 尼特羅會長 VS 全部幻影旅團，哪邊會贏? 7  3/07

# %% [markdown]
# ## 解析內頁
#
# 我們把類似的作法套用在內頁，得到內頁的標題與內文

# %%
def filter_content(content):
    content = content.replace('\n', '')
    match = re.search(r'^(.*?)※\ 發信站:\ 批踢踢實業坊\(ptt\.cc\)', content, re.MULTILINE)
    if match:
        content = match.group(1)
    content = re.sub(r'(<.+?>).*?', '' ,content)
    content = re.sub(r'.*?(</.+?>)', '' ,content)
    print(content[:100])
    
    return content
    # print(content)

# %%
def parse_page(soup):
    meta_data = soup.find_all(class_='article-metaline')
    # 回傳一個 list，分別是: 作者、標題、時間
    # print(meta_data)
    
    author_data = meta_data[0].find(class_='article-meta-value').text
    title = meta_data[1].find(class_='article-meta-value').text
    date = meta_data[2].find(class_='article-meta-value').text
    
    author = author_data.split(' ')[0]
    sign = author_data.split(' ')[1]
    
    print(author)
    print(sign)
    print(title)
    print(date)
    
    # 解析內文
    content = soup.find(id='main-content').contents[4:]
    content = ''.join([str(c) for c in content])
    content = filter_content(content)
    

def crawl_page(page_url):
    # res = requests.get(url=url)
    res = requests.get(url=page_url, cookies={'over18': '1'})
    print('正在爬取', page_url)

    soup = BeautifulSoup(res.text, 'html.parser')
    parse_page(soup)

crawl_page('https://www.ptt.cc/bbs/Gossiping/M.1553696869.A.7F7.html')
crawl_page('https://www.ptt.cc/bbs/Gamesale/M.1553747800.A.799.html')
# Out:
# 正在爬取 https://www.ptt.cc/bbs/Gossiping/M.1553696869.A.7F7.html
# b10485762000
# (台北寂寞部屋)
# [新聞] 88歲老榮民節儉度日 大愛賣屋捐700萬
# Wed Mar 27 22:27:46 2019
# 88歲老榮民節儉度日 大愛賣屋捐700萬中央社 - 2019-03-27 10:13:56（中央社記者魯鋼駿、管瑞平新竹市27日電）新竹榮民之家88歲榮民劉明芝，平時相當節省，一條褲子穿了20多年仍不
# 正在爬取 https://www.ptt.cc/bbs/Gamesale/M.1553747800.A.799.html
# jindulan
# (jindulan)
# [PS4] 徵 全境封鎖2
# Thu Mar 28 12:36:37 2019
# ★【物品名稱】：徵全境封鎖2★【遊戲分級】：限制級★【語系版本】：中文★【徵 求 價】：1400★【交易方式】：面交　【保存狀況】：全新或二手無刮　【地    區】：捷運板橋到西門均可　【附　　註】：

# %% [markdown]
# 現在已經可以爬取「版」頁面的資訊與內頁的資訊了，是時候將他們兩個串在一起，達到自動爬取內頁的功能，整格流程像是：
#
# 爬某個版的某一頁 -> 讀取內頁連結 -> 爬裡面所有的內頁

# %%
import time
base_url = 'https://www.ptt.cc/bbs/'
def crawl_board(board_name, board_page):
    url = base_url + board_name + '/index' + str(board_page) + '.html'

    res = requests.get(url=url, cookies={'over18': '1'})
    print('正在爬取', url)
    save_html(res.text)
    
    soup = BeautifulSoup(res.text, 'html.parser')
    sub_pages = soup.find_all('div', class_='r-ent')
#     sub_pages = sub_pages[:5]
    
    for sub_page in sub_pages:
        
        # 找推數
        push_info = sub_page.find(class_='nrec').find('span')
        if push_info != None:
            num_push = push_info.text
        else:
            num_push = 0
            
        # 找連結資訊
        link = sub_page.find('a')
        link_url = link['href']
        link_title = link.text
        
        # 找日期
        date = sub_page.find(class_='date').text
                
        print(link_url, link_title, num_push, date)
        
        sub_page_base_url = 'https://www.ptt.cc'
        time.sleep(1)
        crawl_page(sub_page_base_url + link_url)
        
        print('')
        print('-------------------')
        print('')
        
crawl_board('Gossiping', 36999)
# Out:
# 正在爬取 https://www.ptt.cc/bbs/Gossiping
3/07
# 正在爬取 https://www.ptt.cc/bbs/Gossiping/M.1551925054.A.FDE.html
# wgadv
# (wga)
# Re: [新聞] 做1天公務員換來冤獄7年！最衰土木教授
# Thu Mar  7 10:17:32 2019
# 其實，台灣不能廢死的真正原因，就是司法體系有問題，部分法官、檢察官及司法人員常常玩法弄法，該辦不辦，不該辦隨便辦。證物可以不細查，證詞能自己推論可信不可信，這種症頭，唯有「司法人員，亂判或栽贓者，最重
#
# -------------------
#
# /bbs/Gossiping/M.1551925085.A.77E.html Re: [爆卦] 中時最新民調 柯文哲GG了 9  3/07
# 正在爬取 https://www.ptt.cc/bbs/Gossiping/M.1551925085.A.77E.html
# macassans
# (Rel4x)
# Re: [爆卦] 中時最新民調 柯文哲GG了
# Thu Mar  7 10:17:59 2019
# 看完這民調柯應該懶得浪費時間金錢了就當他的市長當完接下來照劇本走316民進黨三重麻豆立委輸 卓榮泰請辭125蔡英文連任失敗 民進黨立委腰斬再扣幾席好消息是時代力量大概剩個兩席不分區然後國民黨會不會賣台
#
# -------------------
#
# /bbs/Gossiping/M.1551925130.A.CB1.html Re: [新聞] 最新民調 韓大幅領先柯 5  3/07
# 正在爬取 https://www.ptt.cc/bbs/Gossiping/M.1551925130.A.CB1.html
# silvertime
# (silvertime)
# Re: [新聞] 最新民調 韓大幅領先柯
# Thu Mar  7 10:18:48 2019
# ※ 引述《kcbill (明日やろうは馬鹿野郎だ)》之銘言：: 1.媒體來源:: 中時: 2.完整新聞標題:: 最新民調 韓大幅領先柯: 3.完整新聞內文:: 2019年03月07日 04:11 中國
#
# -------------------
#
# /bbs/Gossiping/M.1551925182.A.EDA.html [問卦] 有沒有系上活動名稱的八卦？在線等 7  3/07
# 正在爬取 https://www.ptt.cc/bbs/Gossiping/M.1551925182.A.EDA.html
# stu00184
# (Wei)
# [問卦] 有沒有系上活動名稱的八卦？在線等
# Thu Mar  7 10:19:39 2019
# 欸幹我新莊小魯蛇啦，最近系上要辦之夜活動，我剛好是召集人之一，主題是紅色為主啦，名字想破頭都想不出來，真的很苦惱，不知道八卦板的魯蛇大大們有沒有什麼好主意啊？採用後小魯願意奉上100p作為謝禮啦！在線
#
# -------------------
#
# /bbs/Gossiping/M.1551925234.A.106.html [問卦] 為什麼插頭有些沒洞 1  3/07
# 正在爬取 https://www.ptt.cc/bbs/Gossiping/M.1551925234.A.106.html
# nike3508
# (QQ)
# [問卦] 為什麼插頭有些沒洞
# Thu Mar  7 10:20:31 2019
# https://i.imgur.com/MLEImi8.jpghttps://i.imgur.com/Cy7Orbe.jpg一般我們比較常用的插頭都有洞有些還會分一大一小 要插進插座要稍微對一下但有些
#
# -------------------
#
# /bbs/Gossiping/M.1551925241.A.FB2.html Re: [問卦] 計程車司機是不是過太爽？ 0  3/07
# 正在爬取 https://www.ptt.cc/bbs/Gossiping/M.1551925241.A.FB2.html
# bebehome
# (bebehome)
# Re: [問卦] 計程車司機是不是過太爽？
# Thu Mar  7 10:20:39 2019
# 奇怪耶，為什麼沒個政府官員支持Uber的當然啦，小黃每天載客吱吱喳喳大談政治影響不少選票，但挺Uber直接獲得Uber用戶支持，趁還沒人敢挺剛好搶頭香藍海一片不管是蔡總統拚外交還是韓市長拚外銷，都關我
#
# -------------------
#
# /bbs/Gossiping/M.1551925267.A.F6D.html Re: [新聞] 潘斯批民主黨：全民健保是社會主義 1  3/07
# 正在爬取 https://www.ptt.cc/bbs/Gossiping/M.1551925267.A.F6D.html
# radiohead56
# (L
# Re: [新聞] 潘斯批民主黨：全民健保是社會主義
# Thu Mar  7 10:21:04 2019
# 這是錯的當然中華民國的社會保險制也是錯的圖利藥商，壓榨護理師跟醫師都是錯的中華民國的健保第一支出是醫藥，也是錯的美國醫療不只要排隊而且費用還很昂貴窮人根本看不起病，只能到藥房買藥所以如果美國有一天推行
#
# -------------------
#
# /bbs/Gossiping/M.1551925301.A.E55.html [問卦] 奧斯卡獎真的有政治正確嘛 9  3/07
# 正在爬取 https://www.ptt.cc/bbs/Gossiping/M.1551925301.A.E55.html
# Twatch
# (code)
# [問卦] 奧斯卡獎真的有政治正確嘛
# Thu Mar  7 10:21:38 2019
# 常常有人說奧斯卡大獎 重要獎項不一定要好看但是所表現意涵一定要政治正確美國真的很重視政治正確嘛--
#
# -------------------

# %% [markdown]
# ## 將結果傳出來
#
# 目前為止做的是「拿到結果就印出來」，但這不利於之後做分析或儲存，所以我們要在函式中回傳爬下來的資料，也就是加上`return`回傳資料
#
#
# ### 儲存格式
#
# 對一個內頁的資訊，我們用一個`dictionary`去存，大致上長這樣
# ```python
# {
#     'author': 作者,
#     'title': 標題,
#     'date': 時間,
#     'content': 內容
# }
# ```
# 要儲存多個內頁的資訊，外面再用一個 `list` 去包起來，會變成像這樣
# ```python
# [
#     {內頁1資訊}, {內頁2資訊}, {內頁3資訊} ...
# ]
# ```

# %%
# 內頁

def filter_content(content):
    content = content.replace('\n', '')
    match = re.search(r'^(.*?)※\ 發信站:\ 批踢踢實業坊\(ptt\.cc\)', content, re.MULTILINE)
    if match:
        content = match.group(1)
    content = re.sub(r'(<.+?>).*?', '' ,content)
    content = re.sub(r'.*?(</.+?>)', '' ,content)
    
    return content

def parse_page(soup):
    meta_data = soup.find_all(class_='article-metaline')
    author = meta_data[0].find(class_='article-meta-value').text
    title = meta_data[1].find(class_='article-meta-value').text
    date = meta_data[2].find(class_='article-meta-value').text
    
    # 解析內文
    content = soup.find(id='main-content').contents[4:]
    content = ''.join([str(c) for c in content])
    content = filter_content(content)
    
    data = {'author': author, 'title': title, 'date': date, 'content': content }
    return data
    

def crawl_page(page_url):
    res = requests.get(url=page_url, cookies={'over18': '1'})
    soup = BeautifulSoup(res.text, 'html.parser')
    data = parse_page(soup)
    
    return data

sub_page_data = crawl_page('https://www.ptt.cc/bbs/Gossiping/M.1553696869.A.7F7.html')

print(sub_page_data)
# 比較漂亮的打印方法
# import pprint
# pp = pprint.PrettyPrinter(indent=4)
# pp.pprint(sub_page_data)
# Out:
# {'author': 'b10485762000 (台北寂寞部屋)', 'title': '[新聞] 88歲老榮民節儉度日 大愛賣屋捐700萬', 'date': 'Wed Mar 27 22:27:46 2019', 'content': '88歲老榮民節儉度日 大愛賣屋捐700萬中央社 - 2019-03-27 10:13:56（中央社記者魯鋼駿、管瑞平新竹市27日電）新竹榮民之家88歲榮民劉明芝，平時相當節省，一條褲子穿了20多年仍不捨丟棄，但他去年卻將賣屋所得700多萬全數捐給新竹榮民之家，善心義舉令人感佩。劉明芝18歲時隨軍隊來台，民國45年上兵退役後擔任清潔隊員，一做就是34年，靠著微薄就養金和清潔員收入度日，節儉的他常一顆饅頭配白開水打發一餐。民國71年時，劉明芝用辛苦存下的新台幣80萬元，在台北市萬華地區買了間公寓，在那裡度過30多年歲月，直到去年入住新竹榮民之家。新竹榮民之家主任陳桂美說，劉明芝的雙親很早就過世，因此他來台70年未曾返鄉探親，甚至沒有出國、離開過台灣這片土地，加上因未婚、沒有子女，一直獨居在萬華小公寓，基本上未享受過親情與物質生活。陳桂美表示，去年9月劉明芝入住新竹榮民之家後，感受到「家」的溫暖，決定把房子賣掉，並將賣屋所得700多萬元全數捐給新竹榮家及榮民榮眷基金會，盼能改善榮家的生活設施。工作人員曾多次勸劉明芝不要捐這麼多錢，但他卻說：「錢財乃身外之物，生不帶來，死不帶去」他想盡些力量回饋照顧他一生的國家。新竹榮民之家工作人員分享，劉明芝相當節省、惜物，至今仍穿著20多年前清潔隊公發的工作褲，即使已多處破洞仍不捨丟棄，常向工作人員借針線縫補，眾人勸他買新褲子，但他總是回應「還可以穿」，儉樸的個性令人敬佩。劉明芝儉樸度日，卻將一生心血捐出，甚至不留分文在身，為感謝他的善心義舉，退輔會近日頒發「榮光專業一等獎章」以表彰他的善行義舉。（編輯：李亨山）10803274.完整新聞連結:https://www.nownews.com/news/20190327/3292747/ --'}

# %%
# 版面頁
base_url = 'https://www.ptt.cc/bbs/'
def crawl_board(board_name, board_page):
    url = base_url + board_name + '/index' + str(board_page) + '.html'
    res = requests.get(url=url, cookies={'over18': '1'})
    
    soup = BeautifulSoup(res.text, 'html.parser')
    sub_pages = soup.find_all('div', class_='r-ent')
    
    # 用一個 list 把內頁資訊存起來
    sub_page_data_list = []
    
    for sub_page in sub_pages:
        
        # 找推數
        push_info = sub_page.find(class_='nrec').find('span')
        if push_info != None:
            num_push = push_info.text
        else:
            num_push = 0
            
        # 找連結資訊
        link = sub_page.find('a')
        link_url = link['href']
        link_title = link.text
        
        # 找日期
        date = sub_page.find(class_='date').text
                
        sub_page_base_url = 'https://www.ptt.cc'
        sub_page_data = crawl_page(sub_page_base_url + link_url) # 注意，把回傳直接起來
        
        # 補上 link 的資訊
        sub_page_data['link'] = sub_page_base_url + link_url
        sub_page_data['num_push'] = num_push
        
        # 在準備好的 list 上加上這個資訊
        sub_page_data_list.append(sub_page_data)
    
    return sub_page_data_list

page_data = crawl_board('Gossiping', 36999)
print(page_data[:5])
# Out:
# [{'author': 'onetwogo (中國優質新聞搬運工)', 'title': '[問卦] 蔡政府不是說超收稅金要發錢補助窮人/?', 'date': 'Thu Mar  7 10:09:21 2019', 'content': ' 大家好 我是窮人 之前政府不是說稅金收了好多， 爽收臺灣人民血汗錢收了這麼多 不是說要發錢補助窮人 怎麼沒消息了?? 怎麼不發了呢?? 這樣不行喔!!!言而無信!!你會連任不了喔!!! 哦!!本來就選不上是嘛?? 民調都最低 所以我是想要問一下啦 政府怎麼不發錢給窮人了呢?? 嘻嘻 ps:台灣窮人素質都很差不用可憐他們，他們死好  我算是特例啦，素質好卻要變窮人!!沒辦法太倒楣了...  科科--', 'link': 'https://www.ptt.cc/bbs/Gossiping/M.1
link': 'https://www.ptt.cc/bbs/Gossiping/M.1551924643.A.86B.html', 'num_push': '13'}, {'author': 'watertoll (奶油QAQ)', 'title': '[新聞] 三立、壹電視新聞台「非洲豬瘟」內容遭NC', 'date': 'Thu Mar  7 10:12:46 2019', 'content': '1.媒體來源:ETtoday2.完整新聞標題:三立、壹電視新聞台「非洲豬瘟」內容遭NCC警告、要求改進3.完整新聞內文:記者陳世昌／台北報導三立新聞台、壹電視新聞台因播出「中國大陸非洲豬瘟疫情」有關內容，違反衛星廣播電視法、電視節目分級處理辦法，NCC(國家通訊傳播委員會)6日決議發函警告與要求改進。NCC發言人翁柏宗表示，三立新聞台「新台灣加油」節目於107年12月19日討論「非洲豬瘟疫情蔓延中國大陸，撲殺防疫亂套」議題時，播出處理感染非洲豬瘟豬隻相關新聞影片，出現病豬遭火焚燒掙扎逃竄畫面及慘叫聲。由於該節目播出時聲音與畫面均未做處理，違反衛星廣播電視法第28條第1項規定、電視節目分級處理辦法、衛星廣播電視法第52條第1項第3款規定，決議裁處警告。壹電視新聞台於107年12月25「1400整點新聞」節目，播出「非洲豬瘟蔓延 廣州火燒6千隻活體豬」新聞報導，主播口述：「非洲豬瘟疫情在中國蔓延，廣州市一處養豬場，有6千隻豬被活埋，網路上現在還出現了一段畫面，多隻疑似病發的活體豬被丟入坑內活活給燒死，這景像很殘忍，……。」等內容。記者說明：「……畫面上我們可以看到一隻又一隻活生生的豬，被人丟入深達10多公尺的坑洞中，坑內是鋪滿稻草等一些易燃物，沒想到下一秒，村民直接丟下火種，把這些豬隻活活給燒死。現場還有聽見動物淒厲的尖叫聲，而且沒有間斷過，這些遭到火燒的豬隻，在坑內痛苦的四處亂竄。NCC表示，壹電視該段內容殘忍畫面雖有馬賽克處理，但聲音並未處理，將發函要求改進。4.完整新聞連結 (或短網址):https://bit.ly/2tU8Vs45.備註:NCC最公正，打擊假新聞不遺餘力！--https://i.imgur.com/S2VANmt.jpg--', 'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551924769.A.1C4.html', 'num_push': 0}, {'author': 'smalltwo (獎金獵人)', 'title': 'Re: [問卦] 尼特羅會長 VS 全部幻影旅團，哪邊會贏?', 'date': 'Thu Mar  7 10:12:53 2019', 'content': '念能力的對決沒有絕對我以為這是獵人基本的常識如果硬要去比我會押會長贏但是應該會6:4開以會長念能力的水平他走的方向幾乎是單打無敵的蟻王會贏靠的是念的量蟻王念驅動的堅擋下所有的攻擊等待會長力竭幻影旅團中是否有人有這樣的能耐擋下呢?看起來是沒有那麼是否有人速度能躲過呢?照蟻王的測試結果看來應該有機會畢竟旅團有這麼多人百式觀音的拳頭和掌會分給全部人去承擔能閃過以後讓特質系的近身才有可能贏但是我覺得拉..機會應該不大不過人多還是有好處的※ 引述《bigrange (bigrange)》之銘言：: 幻影旅團是惡名昭彰的犯罪集團: 如果，尼特羅會長 VS 全部幻影旅團，哪邊會贏?--', 'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551924775.A.CE4.html', 'num_push': '7'}]

# %% [markdown]
# ## 處理多頁的資訊
# 剛剛我們都以讀八卦版的第36999頁為例，現在我們設定一個頁數範圍，讀取每一頁，然後把資訊併在一起
#
# ### 補充
# 這裡的`try`是用來避免我們在爬取資料的時候遇到沒考慮到的錯誤，意思是，如果爬取這頁時遇到問題，就跳過它，用來節省一些麻煩。

# %%
def crawl_board_with_range(start, end):
    
    board_data = []
    for page_id in range(start, end):
        print('爬取第', page_id, '頁')
        try:
',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551060451.A.679.html',
#   'num_push': 0},
#  {'author': 'sawkuanwoo (大家快來darkchess下暗棋)',
#   'title': 'Re: [新聞] 立委補選最新民調！民進黨恐全軍覆沒',
#   'date': 'Mon Feb 25 10:07:52 2019',
#   'content': '※ 引述《stevencool (政治好複雜)》之銘言：: ※ 引述《hTcCherWang (神愛世人)》之銘言：: : 別的不說 說說我選區的台南二: : 這區民進黨應該是穩翻船了: : 謝龍介到這裡來一堆人堵著跟他合照 排隊拍照大概要20-30分鐘才輪得到: : 郭來這一區跟都市人下鄉視察你們村民過的好不好一樣 簡單來說就是馬英九模式: : 至於還有一個雜魚我忘記叫什麼名字了 看板也是很多 但很難讓人有印象: : 其實看完很感慨 以前都是國民黨天龍人高高在上: : 南部人要見官還要申請: : 現在整個反過來了 慟: 個人看法是賴清德太過霸氣，其實這選區民進黨最強的人選是陳致中，但賴清德要他不要回台南選（當然這阿扁當方面的講法啦，看看新勇哥物語阿扁談派系），賴清德非要一個關廟人郭國文選，還做掉扁媽乾孫女，不過陳致中還是很有機會，下屆官田要併進來這區，致中哥回鄉參選相信麻豆官田人會支持的: -----: Sent from JPTT on my HTC_U-3u.台南就是賴的新潮流 VS 扁的一邊一國二方為了台南市長去年初選打成這樣大家都看在眼里了最後還是新潮流拿下可是初選這打法二派根本沒機會再好好合作結果讓偉哲雖然當選但票數很難看新潮流這種吃乾抹淨不吐骨头的作風讓其他派系非常不滿你都拿下市長了肉吃了至少菜或湯分些給人吧抱歉一滴湯都别想議長選舉那個喬法中央都説不合規定抱歉我大新潮流說一不二議長要副議長也該給人吧對不起我全都要最後結果大家都知道了黨内大分裂脱黨+跑票讓你新潮流不但沒議長連副議長都沒有如果是務實的人既然知道自己沒法一手遮天就應該好好坐下來跟隊友合作了抱歉會這樣還叫新潮流嗎第二選區立委補選即使只有1年任期我還是要吃可是本區沒自己人阿沒關係我空降一個來空降的民調比不過在地的怎麼辦簡單黑箱戳掉就好啦現在dpp二個派系都出人了随然只有一個挂dpp黨但是在台南不算什麼dpp到現在根本不敢把矛頭對小魚只能去打龍介即使知道自己要是輸最大原因是小魚分票新潮流這搞法dpp永遠别想要團結了--posted from bbs reader hybrid on my LENOVO Lenovo B8000-H--如何嘴砲  反駁對方的重點──◢◣█確實指出人家論點的錯誤性  ψQSWEET駁斥──────◢ ◣█用引言指出對方錯誤或矛盾的地方( █優質論文)在嘴砲王 相反的觀點──◢████◣█列出相反的論點並以事實當證據( █ 辯論社)應該出現 矛盾────◢██████◣█列出相反的論點但不加以證實( ██論壇)的元素   攻擊態度─◢████████◣█質疑對方的態度和口氣    ( ██匿名版)人身攻擊↘偏見↗  ▄▄▄▄▄▄▄▄▄▄▄▄█攻擊身份和能耐█Ｘ你娘(█ 小朋友)  --',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551060474.A.08D.html',
#   'num_push': 0},
#  {'author': 'toshbio (toshbio)',
#   'title': '[新聞] 羅霈穎光收租「夠養自己一輩子」:擁5間?1',
#   'date': 'Mon Feb 25 10:08:25 2019',
',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551060515.A.AF1.html',
#   'num_push': '9'},
#  {'author': 'godend (還是 有希望的)',
#   'title': '[問卦] 急！請問考多少上的了台大？',
#   'date': 'Mon Feb 25 10:09:02 2019',
#   'content': '：：：：--小妹剛剛收到成績單ㄌ跟對答案的時候差好多QQ總共結果如下：國5英3數1社4自2請問這樣上的了台大嗎？？我不想去臭臭的理工大學喇好急好急嘻嘻--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551060545.A.825.html',
#   'num_push': 0},
#  {'author': 'Changyaya ()',
#   'title': '[問卦] 貓貓把充電線咬壞 要怎麼懲罰',
#   'date': 'Mon Feb 25 10:09:33 2019',
#   'content': '安安昨天剛買了子龍機啦今天在充電時出門買個早餐回來充電線就被咬壞了https://i.imgur.com/u22iwZF.jpg請問要怎麼懲罰他啦兇手本人https://i.imgur.com/cqBXLqm.jpghttps://i.imgur.com/KjnqKnb.jpg他喜歡有電的地方的樣子...--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551060576.A.867.html',
#   'num_push': '76'},
#  {'author': 'wwwson1256 (太陽花青年)',
#   'title': '[問卦] 1920年的美國比2019台灣先進？',
#   'date': 'Mon Feb 25 10:10:16 2019',
#   'content': '1920年的美國無論是硬體建設、交通建設、治安秩序似乎贏過2019的台灣是什麼原因造成台灣落後美國將近100年？連軟體建設也屌打--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551060618.A.3CD.html',
#   'num_push': 0},
#  {'author': 'tello (妳高興就好~)',
#   'title': 'Re: [問卦] 常到超商收發包裹算奧客嗎？',
#   'date': 'Mon Feb 25 10:10:33 2019',
#   'content': '當然是阿。根本人渣廢物。尤其是搞網購的為了省那個運費在那邊天天來亂，每天看他們在佔用櫃檯的時間實在是欠人幹啊引述《Savior09 (Sakana Mazui)》之銘言：: 現在超商服務包山包海: 能代收包裹也能寄: 對上班族來說真的很方便: 但店員可就慘了: 每次看到前面領包裹的在拖台錢: 店員臉臭的跟屎一樣: 就覺得他們很辛苦: 還要兼管理員+郵局: 身兼數職沒加薪: 如果附近居民有愛逛網拍、團購的: 一個就能搞死店員吧: 這樣算是奧客嗎？: -----: Sent from JPTT on my iPad-----Sent from JPTT on my Asus ASUS_X00TDB.--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551060635.A.E67.html',
#   'num_push': '3'},
#  {'author': 'pchunters123 ()',
#   'title': 'Re: [問卦] 不允許中天新聞? 鄭南榕主張100%言論',
#   'date': 'Mon Feb 25 10:11:27 2019',
#   'content': '※ 引述《Bignana (習維尼你媽北七超級北七)》之銘言：: 其實我不知道為什麼會滑坡到言論自由，: 八卦板板規中的備註1「可張貼新聞網站」行之有年，: 若有張貼需求，可至 GossipPicket 申請。其實就是很簡單：『家規自訂』就好像你跑去日旅版貼政治文被水桶也是應該的跟言論自由有啥關係？不爽就走ptt流程把這條家規改掉沒人有意見: 我也直接說啦，如果真的有人申請，「中天新聞」為本板可張貼新聞的媒體，: 我會拒絕。: 1.中時電子報太多社論特稿故意放在新聞分類中，破壞媒體第四權的自律。:   身為同系統，中天新聞若申請，我會拒絕: 2.太多跳板IP故意張貼這種放在新聞分類的特稿，於本板進行特定圖謀。結果硬要扯到『破壞第四權自律』那被用同樣標準檢視其他媒體也是很正常--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551
入管制區立刻被機場地勤人員發現，並通報攔查，並非如報導在停機坪停留整夜睡覺。遭攔查地點位於松山機場緊臨貨運站機坪，與軍用機坪無關，距離空軍一號停機坪更是相隔甚遠，空軍一號停機坪也無遭外人闖入。（突發中心高鈞麟／台北報導）https://tw.appledaily.com/new/realtime/20190225/1523210備註:GTA 怎麼沒去偷開戰機 然後降落在高速公路上1.媒體來源:※ 例如蘋果日報、自由時報2.完整新聞標題:※ 標題沒有完整寫出來 ---&gt; 依照板規刪除文章3.完整新聞內文:※ 社論特稿都不能貼! 違者刪除(政治類水桶3個月)，貼廣告也會被刪除喔!4.完整新聞連結 (或短網址):※ 當新聞連結過長時，需提供短網址方便網友點擊5.備註:※ 一個人一天只能張貼一則新聞，被刪或自刪也算額度內，超貼者水桶，請注意--新北鍵盤帥哥名冊 1F:三重劉德華  2F:蘆洲郭富城  3F:五股張學友  4F:副都心黎明  5F:淡水拓也哥 6F:板橋李宗瑞  7F:臉書李富城  8F:新店彭于晏  9F:三峽羅志祥 10F:土城土豪哥11F:深坑李大仁 12F:汐止陳冠希 13F:泰山柯震東 14F:中和周渝民 15F:樹林趙又廷16F:永和阮經天 17F:林口余文樂 18F:烏來吳克群 19F:北車金城武 20F:八卦版肥宅--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551060997.A.BE5.html',
#   'num_push': '2'},
#  {'author': 'stupigII (有遺憾，也不要有後悔)',
#   'title': '[問卦] 社會信用評分制度對阿宅的影響?',
#   'date': 'Mon Feb 25 10:16:48 2019',
#   'content': " 試論 ,社會信用評分制度之於患有社會性交流障礙不健全的人之影響??? 我的作業不想自己寫,所以來問問~--Woman, thou hast encircled the world's heart...          With the depth of thy tears as the sea has the earth.......--",
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551061013.A.BCB.html',
#   'num_push': 0},
#  {'author': 'ttn851227 (beyond218)',
#   'title': 'Re: [問卦] 國12 英14 數12 自11 可以讀什麼？',
#   'date': 'Mon Feb 25 10:17:49 2019',
#   'content': '幫你算一下（12+14+12+11）=49如果有高級A原住民人種血統則最終分數是（12+14+12+11）X1.35=66.15四捨五入 66級分我推測今年台大醫科最高才60級分66級分 大葉醫科應該可以拼一下，專心準備二階--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551061071.A.90C.html',
#   'num_push': '1'},
#  {'author': 'fidelity77 (小柚)',
#   'title': 'Re: [問卦] 不允許中天新聞? 鄭南榕主張100%言論自由',
#   'date': 'Mon Feb 25 10:18:53 2019',
#   'content': '奇怪了是誰跟你說ptt有100%言論自由八卦版本來就沒有100%言論自由阿不然板規寫得落落長是在寫三小政問也被禁、佛地魔也被禁、求車票也會被刪怎麼沒人出來灣--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551061135.A.9B0.html',
#   'num_push': '1'},
#  {'author': 'Aqqqa (Aqqqa)',
#   'title': '[新聞] 學測數學7782人滿級分\u3000較去年大增1.1倍',
#   'date': 'Mon Feb 25 10:19:00 2019',
#   'content': 'https://tw.news.appledaily.com/life/realtime/20190225/1523241/蘋果日報學測數學7782人滿級分\u3000較去年大增1.1倍出版時間：2019/02/25 09:5813.8萬餘人報考的108學年度學科能力測驗，大學入學考試中心今天公布成績相關統計資料，在各科滿級分與零級分人數，根據大考中心資料，在「國英數社自」五科當中，滿級分人數分別為4438人、7689人、7782人、2575人、4135人，其中除了社會科滿級分人數較去年減少1692人之外，其餘4科滿級分人數都較去年增加，其中又以數學滿級分人數較去年的3700人大增4082人，增加達1.1倍，另外自然科也從去年2912人，增加1223人滿級分，另外國文、英文則較去年分別增加674人、282人。至於零級分部分，「國英數社自」五科，分別有7人、9人、41人、9人、11人零級分，其中數學零級分人數從去年59人降為今年41人，其餘4科零級分人數皆較去年增加。（許敏溶／台北報導）--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551061143.A.23B.html',
#   'num_push': '3'},
#  {'author': 'saskuran (beyourguard)',
#   'title': '[問卦] 等一下第一科考英文怎麼辦',
#   'date': 'Mon Feb 25 10:19:02 2019',
#   'content': '餓死抬頭小弟學測生啦等一下第一科考英文但7000單小弟只背到abandon想問一下有什麼秘訣可以拿15級乾五八卦--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551061144.A.B6C.html',
#   'num_push': '5'},
#  {'author': 'koberaper (饒舌歌手狗鼻)',
#   'title': 'Re: [問卦] 不允許中天新聞? 鄭南榕主張100%言論自由',
#   'date': 'Mon Feb 25 10:19:37 2019',
#   'content': '板上一堆學店覺青最愛在那邊搞論述整天嗆啥做智力測驗 不要笑死人一個言論自由 各自表述期望哪天可以選一個政治偏藍的版主出來用同樣標準處理三民自反正也他媽也一堆假新聞假民調要不是現在民進黨正處低點 三民自造神還不造起來？到時候用同樣標準鎖這幾家綠共媒體看版上廠工會不會一堆屁話--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551061180.A.D90.html',
#   'num_push': 0},
#  {'author': 'j55888819 (下露顆‧撫耳摸濕)',
#   'title': 'Re: [新聞] 為了高雄...晚宴苦等不到吉隆坡市長\u3000韓',
#   'date': 'Mon Feb 25 10:19:50 2019',
#   'content': '※ 引述《opica (op)》之銘言：: TVBS: 為了高雄...晚宴苦等不到吉隆坡市長\u3000韓國瑜說話了！: 高雄市長韓國瑜24日出訪馬來西亞，傳出原本安排晚宴跟吉隆坡市長見面，卻沒有任何馬: 來西亞的官方代表出席，遭外界質疑遭受打壓。對此，韓國瑜表示，「行程調整跟改變並: 不是我們想要的，我們完全尊重對方的決定。」: 韓國瑜指出，昨天晚宴有些官員未能出席，對高雄市來講有點可惜，因為每一個東南亞的: 城市都非常重要，能多結交一些朋友、行銷高雄，我們都樂意去做。他也表示，「行程調: 整跟改變並不是我們想要的，對方如果有這樣的考量，我們完全尊重。」: 包括昨晚的吉隆坡市長、農業部長加上今早的國會議員，都因為有各自的考量未能見面，: 至於下午原本預定要跟發展部部長見面，會不會擔心出現一樣狀況？韓國瑜表示，計畫趕: 不上變化，還是尊重，我們現在人在馬來西亞，他們一切的改變、調整我們都尊重，他也: 表示不需要評論太多，「為了高雄跟以後對外的發展，我們都是尊重，也都是感謝。」: https://news.tvbs.com.tw/politics/1088594這讓我想到阿上次我去日本玩的時候我本來也想和天皇或是安倍總理見個面做做國民外交結果他們都沒有來找我讓我當天晚上心情都很鬱卒去吃迴轉壽司也才吃五盤而已當下也有點懷疑背後是有政治力量在打壓所以今天看到韓市長的處境令我也十分感同身受希望大家給韓市長一聲加油 好嗎?順帶一提日本的抹茶真的好好吃喔 嘻嘻--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551061192.A.424.html',
#   'num_push': '3'},
#  {'author': 'ZEUS5566 (宙斯56)',
#   'title': '[問卦] 你是小魏 你還想上台大醫嘛?',
#   'date': 'Mon Feb 25 10:20:08 2019',
#   'content': '如題!!假如你是小魏 成績出來了(應該是滿級分啦)你還會填台大醫嘛?去給小石跟二馬(或學長姐暗地裡)看笑話? 還是拼給他們看還是會填陽明 或高醫之類的?  老死不相往來?還是想個辦法去國外???有卦嘛?--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551061210.A.7DB.html',
#   'num_push': '76'},
#  {'author': 'a78914124 (U文製造機)',
#   'title': '[問卦] 奧斯卡捧覽趴也捧得太難看惹吧?',
#   'date': 'Mon Feb 25 10:21:02 2019',
#   'content': '幹 轉開電視看一下奧斯卡阿結果 黑豹兩座 波西米亞三座 ROMA一座幹 不是給黑人就是給同性戀唯一不是黑人不是同性戀的是Latino這根本就政治正確就得獎吧奧斯卡會不會太會捧覽趴阿--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551061265.A.5EE.html',
#   'num_push': '19'},
#  {'author': 'tetani (喵喵)',
#   'title': 'Re: [新聞] 立委補選最新民調！民進黨恐全軍覆沒',
#   'date': 'Mon Feb 25 10:21:23 2019',
#   'content': '※ 引述《deann (古美門上身)》之銘言：: : 個人看法是賴清德太過霸氣，其實這選區民進黨最強的人選是陳致中，但賴清德要他不要回台南選（當然這阿扁當方面的講法啦，看看新勇哥物語阿扁談派系），賴清德非要一個關廟人郭國文選，還做掉扁媽乾孫女，不過陳致中還是很有機會，下屆官田要併進來這區，致中哥回鄉參選相信麻豆官田人會支持的: 這不是霸氣不霸氣的問題 而是這區本來黃偉哲的席次 利益交換好已經要給新潮流了: 所以人渣文本才說台南這席補選 是新潮流的老巢命脈的保衛戰 甚至影響賴清德前途: 從段宜康前天開始砲轟謝龍介開始  果然這一兩天鄭文燦也南下助選了: https://udn.com/news/story/7326/3661190: 賴清德就別提了 本來就駐守在台南用力幫郭國文操盤 打政治前途保衛戰: 很可能陳菊花媽也會南下 幫郭國文站台  梁文傑上政論幫郭國文嗆謝龍介: 新潮流幾乎全體總動員挺郭國文了 還幫郭國文動員遊覽車造勢郭國文一例一修太傷了，讓勞工沒辦法多加班賺錢的罪人這次中南部1124淪陷，就是一例一修害的dpp趕緊啟動修法，取消加班限制才能拯救選情--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551061286.A.13E.html',
#   'num_push': '7'},
#  {'author': 'oooo (法性本寂隨緣轉)',
#   'title': 'Re: [新聞] 學測數學7782人滿級分\u3000較去年大增1.1倍',
#   'date': 'Mon Feb 25 10:21:44 2019',
#   'content': '現在這種評分方式鑑別度太差應該改成滿分1000分數學佔500分其它科目合計500分英文不考這樣才對數學佔比高,可以把笨蛋刷掉...--8歲童上廁所被自家養的狗咬死\u3000父淚崩：他們從小一起長大https://www.ettoday.net/news/20180824/1242759.htm悉心飼養9年 她被毛畜狠心撕裂手臂 (左手臂必須截肢)http://news.ltn.com.tw/news/world/breakingnews/2332023不繫狗繩令兩狗大戰\u3000女飼主被咬到胸部切除乳房https://tw.appledaily.com/new/realtime/20181125/1473025/--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551061312.A.63F.html',
#   'num_push': '1'},
#  {'author': 'B0858B ()',
#   'title': '[新聞] 韓國瑜訪馬來西亞第2日 傳與馬國發展企業',
#   'date': 'Mon Feb 25 10:22:01 2019',
#   'content': '1.媒體來源：聯合※ 例如蘋果日報、自由時報2.完整新聞標題：韓國瑜訪馬來西亞第2日 傳與馬國發展企業部長見面※ 標題沒有完整寫出來 ---&gt; 依照板規刪除文章3.完整新聞內文：※ 社論特稿都不能貼! 違者刪除(政治類水桶3個月)，貼廣告也會被刪除喔!高雄市長韓國瑜24日出訪馬來西亞，但並未與馬國官員會面，不過傳出25日一早先接受馬國媒體專訪，再與馬國國會議員共進早餐，之後舉行貿易商簽約及推廣會，預計馬來西亞發展企業部部長將出席。此次星馬行，高市府保密到家，給媒體的行程相當簡約，僅寫貿易商、通路商簽約，但哪家貿易商、通路商不講，有無與官員碰面也不透露，甚至到了馬來西亞，也堅持「到了就知道」，未到行程地點都不肯說。不過台灣媒體版的行程精簡，但馬來西亞媒體版的行程可就截然不同，台媒版行程25日只有上午貿易商簽約和推廣會，但馬媒版行程則是一大早8點30分接受大馬透視視頻專訪推廣高雄農產品，再與馬來西亞國會議員早餐會，接著舉辦高雄農產推廣會，與吉隆坡Euro-atlantic簽約，並預計馬來西亞發展企業部部長出席。韓國瑜24日晚宴，雪蘭莪賽馬公會主席、馬來西亞賽馬總會委員丹斯里拿督詹學龍也邀韓國瑜25日下午帶高市府團隊參觀馬來西亞馬場，交流賽馬經驗。讓台、馬媒體版外的行程又多了一筆。4.完整新聞連結（或短網址）：https://udn.com/news/story/6656/3663169--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551061323.A.032.html',
#   'num_push': 0},
#  {'author': 'toolittle (蘆洲良心燈塔)',
#   'title': '[問卦] JoJo最實用的替身是哪一個',
#   'date': 'Mon Feb 25 10:23:44 2019',
#   'content': '安安我大叔啦 aka 蘆洲良心燈塔餓死抬頭JoJo的奇幻冒險算長青漫畫了目前一共出了8部JoJo歷史裡替身能力有好幾種只要遇到莫名其妙的事說一句這是替身攻擊就可以解釋一切不得不佩服荒木飛呂彥老師的腦洞請問哪一個替身能力最實用我個人認為是白金之星.世界暫停世界10秒左右夠我喔啦 喔啦 射好幾次了嘻嘻-----Sent from JPTT on my Samsung SM-G9208.--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551061426.A.BB1.html',
#   'num_push': '28'},
#  {'author': 'CLV518 (ANON)',
#   'title': '[新聞] 展現強力領導 川普改變美中貿易談判定位',
#   'date': 'Mon Feb 25 10:24:30 2019',
#   'content': '1.媒體來源:※ 例如蘋果日報、自由時報大紀元2.完整新聞標題:※ 標題沒有完整寫出來 ---&gt; 依照板規刪除文章展現強力領導 川普改變美中貿易談判定位3.完整新聞內文:※ 社論特稿都不能貼! 違者刪除(政治類水桶3個月)，貼廣告也會被刪除喔!週日（2月24日），距離3月1日停火時限不到六天的時間，美中談判官員在華府繼續談判。在最後衝刺階段，川普（特朗普）總統上週五（22日）要求雙方主談人做一件事，為未來協議取得更適當的位階。週日，美中新一輪延長談判的第二天，美國貿易代表羅伯特‧萊特希澤（Robert Lighthizer）及財長史蒂芬‧姆欽（Steven Mnuchin）與習特使劉鶴
10月在「美台國防工業會議」發表演說時，力陳台灣國防預算太少，發展應考量可靠、韌性與成本效益。AIT主席莫健也曾提到，台灣不要為了未來的能力而放棄現在的即戰力；美方鼓勵台灣加倍努力，為強化有效全面防禦做好準備，這將需要進一步投資國防，並加強其儲備與徵召制度。莫健也曾指出，面臨重大威脅的國家如南韓、以色列，還是維持徵兵制，台灣若要推行全募兵制，需做足相關準備，同時展現捍衛自己的決心。另外，曾任美國國務院亞太副助卿的柯慶生（Thomas Christensen）也曾表示，台灣改為全募兵制會導致軍隊更小、更昂貴，也不符合台灣的戰略，直指台灣在軍事方面沒有做好充分凖備，將無法遏阻中國可能以武力威迫台灣，盼台灣能將募兵制視為實驗，之後回到傳統的徵兵制度。ETtodayhttps://www.ettoday.net/news/20190220/1381555.htm--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551061566.A.C45.html',
#   'num_push': 0},
#  {'author': 'manysheep (愛與和平的PTT鄉民)',
#   'title': '[問卦] 台灣的飛彈最遠可以打到中國那邊？',
#   'date': 'Mon Feb 25 10:26:07 2019',
#   'content': '台灣的飛彈最遠到底可以打到中國那邊阿？北上廣深 能打到嗎？西安、成都呢？畢竟如果中國攻台我覺得如果戰場只在台灣那只有中國政權能抓得緊  對他們來說只是錢的問題 成本太低這也是中國民眾會支持的原因但如果台灣有能力放話只要中國一攻台台灣就打著玉石俱焚的決心北上廣深西安武漢成都統統各大都市丟個一千枚飛彈如果飛彈穿透力越強越好 能打爆大壩更好抱著你若敢攻台 那就兩岸一起死的想法這樣發動攻台戰的成本就高很多了歷史上是有國家這樣搞的強國不敢攻畢竟強國的敵人太多攻打你的成本太高 就不會發動如果戰場只在台灣 那對中國只是解放軍跟錢的問題對中國太子黨、民眾 成本都太低了但如果台灣的飛彈能打很遠那戰場就不只在台灣了發動戰爭的成本就很高願意支持發動戰爭賭上自己不會被打到的人就少了所以 台灣飛彈 到底能打到中國那邊？應該把花大錢去研發增加導彈距離挖人才 花大錢研發應該是值得的台灣如果只能防守 對中國來說成本也太低如果台灣還能攻擊到中國內陸 對中國成本就高了這個藍綠白都應該支持吧贊成就推吧希望政府多花錢在研發增加導彈距離--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551061569.A.1F4.html',
#   'num_push': '2'},
#  {'author': 'c8c8c8c8c8c8 (哈哈哈哈哈哈哈哈哈哈哈)',
#   'title': 'Re: [新聞] 翁啟惠團隊研究成功 新流感疫苗效果強4倍',
#   'date': 'Mon Feb 25 10:25:54 2019',
#   'content': '※ 引述《Nicher (rehciN)》之銘言：:  這沒可能會被藥廠採用:  我們想一下流感疫苗是要做啥的 主要是要賺錢用的:  你今天弄一個長效疫苗出來 四年才打一次:  那他們還賺甚麼?:  如果改成每年都打 但價錢比一般疫苗貴:  消費者誰去買呢?:  綜合上面兩點 看不出利基在哪:  但是能發paper的好材料假設舊疫苗一支一百塊，每年打一次    新疫苗一支四百塊，四年打一次這樣廠商會比較想打哪個??這個問題重點並不是疫苗的本身差異或是利基市場在哪而是廠商本身的商業模式這兩種商品的操作模式不同，鎖定客群也不同對一些現金為王的廠商而言，這樣的差異並不是打一次很久都沒訂單，而是可以把現金先拿到手上原本舊疫苗還會面對不同廠商同質商品的競爭新的疫苗『不用每年都去打』這點不就是他市場區隔? 不就是利基市場所在?--→ realtw: 經濟學人?哈 原來加上這四個字 連人名都沒有的就變權威了11/16 14:19→ realtw: 我也是經濟學人 我權威嗎                              11/16 14:19→ realtw: 台日韓新某經濟學家=全世界=權威                       11/16 14:21→ realtw: 知道啊 經濟學人是英國一個小報啊 就是故意留梗啊       11/16 14:42→ realtw: 本來就是酸這個野雞雜誌有沒有權威性 你還較真上了XD    11/16 14:43--',
#   'link': 'https://www.ptt.cc/bbs/Gossiping/M.1551061579.A.39E.html',
#   'num_push': '4'}]

# %% [markdown]
# ## 完成了，然後呢？
# 我們成功的把ptt某個版的資訊爬下來了，然後可以做些什麼？
#
# 1. 把 `board_data` 存下來
# 2. 對 `board_data` 分析或是搜尋

# %% [markdown]
# ## 儲存方法
# 儲存資料的方法有很多種，我們這裡採取比較簡單的方式，利用`pickle`直接把 Python 的陣列存成一個檔案。
#
# 這裡提供了儲存與讀取的寫法，如果已經爬過並且儲存起來，就可以只要讀取就好，把其他的部分註解掉。

# %%
import pickle

# 注意：跑[35000, 35100]有ㄧ100頁，約要一個小時以上。
board_data = crawl_board_with_range(35000, 35100)

# 將爬下來的資料 list 存成 board_data.pkl
with open('board_data.pkl', 'wb') as output:
    pickle.dump(board_data, output)

# 將 board_data.pkl 讀出來到 loaded_board_data 這個變數
with open('board_data.pkl', 'rb') as input:
    loaded_board_data = pickle.load(input)
    print(len(loaded_board_data))
# Out:
# 1980

# %% [markdown]
# ## 簡單的應用
# 在所有的文章中搜尋關鍵字，並且印出搜尋到的文章的相關資訊。
#
# 小提醒，我們儲存的資料長這樣
# ```python
# [
#     {內頁1資訊}, {內頁2資訊}, {內頁3資訊} ...
# ]
# ```

# %%
# board_data = crawl_board_with_range(35000, 35500)

def search_word_in_data(data, keyword):
    for page_data in data:
        if keyword in page_data['content']:
            print('在', page_data['title'], '找到', keyword, '關鍵字')            
            print('連結:', page_data['link'])

# 直接把我們儲存的資料讀出來的那份丟進去
search_word_in_data(loaded_board_data, '急診')
# Out:
# 在 [新聞] 小六轉學生淪人肉沙包　同學陰狠四招害렱 找到 急診 關鍵字
# 連結: https://www.ptt.cc/bbs/Gossiping/M.1550291348.A.6E3.html
# 在 Re: [問卦] 台女到底討不討厭小馮這樣劈腿的行為？ 找到 急診 關鍵字
# 連結: https://www.ptt.cc/bbs/Gossiping/M.1550298711.A.6F2.html
# 在 [問卦] 大夜急診護理工作妹子 找到 急診 關鍵字
# 連結: https://www.ptt.cc/bbs/Gossiping/M.1550312538.A.843.html
# 在 [新聞] 段宜康料理大螃蟹　慘！秒遭夾傷拇指就醫 找到 急診 關鍵字
# 連結: https://www.ptt.cc/bbs/Gossiping/M.1550331900.A.EB5.html
# 在 [問卦] 有原住民醫師不是加分仔的嗎？ 找到 急診 關鍵字
# 連結: https://www.ptt.cc/bbs/Gossiping/M.1550347218.A.95F.html
# 在 [問卦] 醫生是不是10年內會變低薪族群？ 找到 急診 關鍵字
# 連結: https://www.ptt.cc/bbs/Gossiping/M.1550361516.A.2D2.html
# 在 Re: [問卦] 醫生是不是10年內會變低薪族群？ 找到 急診 關鍵字
# 連結: https://www.ptt.cc/bbs/Gossiping/M.1550366373.A.2CA.html
# 在 Re: [問卦] 醫生是不是10年內會變低薪族群？ 找到 急診 關鍵字
# 連結: https://www.ptt.cc/bbs/Gossiping/M.1550371046.A.963.html
# 在 [新聞] 勇！半馬女跑者完賽前遭大狗猛咬 浴血衝 找到 急診 關鍵字
# 連結: https://www.ptt.cc/bbs/Gossiping/M.1550373327.A.471.html
